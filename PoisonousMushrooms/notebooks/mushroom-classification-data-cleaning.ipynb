# %% [markdown]
# <h1 style='text-align:center;font-size:36px;color:#333;background-color:#f9f9f9;padding:10px;border-radius:5px;'>🍄 Poisonous Mushroom EDA 🍄</h1>
#
# <img src="https://as1.ftcdn.net/v2/jpg/06/68/49/66/1000_F_668496640_mlxNRt7nqCtEZti4gXv5w5NbC8yn9fgx.jpg" alt="Mental Health Image" style="display:block;margin-left:auto;margin-right:auto;width:70%;">
#
# <!-- <div style="background-color:#20BEFF;
#             border-radius: 7px;
#             padding: 21px;
#             font-size:18px;
#             font-family: 'Roboto', sans-serif;
#             line-height: 1.7em;">
# <p style="color:white">Please don't hesitate to customize or modify the notebook to suit your needs. If you've found the notebook helpful, kindly consider giving it an upvote. Your feedback and support are incredibly valuable and serve as motivation for me to produce more notebooks akin to this one.</p>
# </div> -->

# %% [markdown]
# # <center><div style="font-family: 'Roboto', sans-serif;"> 📚 Introduction  </div></center>
# <div style="background-color:#7FFFD4;
#             border-radius: 7px;
#             padding: 21px;
#             font-size:18px;
#             font-family: 'Roboto', sans-serif;
#             line-height: 1.7em;">
#     <p style="color:black">A mushroom (also called a toadstool) is the part of a fungus that is comparable to the fruit of a plant. Unlike plants, mushrooms do not use sunlight to generate energy for themselves. Some mushrooms are edible, and are used for cooking in many countries, such as China, Korea and Europe. Other mushrooms, however, are poisonous, and can cause severe illness or death if eaten. People who search for edible mushrooms are called mycophagists, meaning "mushroom eater", while the act itself is called "mushrooming". Mushrooms have been known to support bone health and to regulate blood sugar in diabetics. It is available in different colours and shapes.
# </div>

# %% [markdown]
# <div id = 'h1'  class = 'alert alert-block alert-info' style=" 5px solid #f0ad4e; background-color: #00FFFF; padding: 10px;">
# <h2>😉👉 Importing Libraries:</h2>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn import preprocessing
import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv("/kaggle/input/playground-series-s4e8/train.csv", index_col = 'id')
df_train
# Out:
#         class  cap-diameter cap-shape cap-surface cap-color  \
# id
# 0           e          8.80         f           s         u
# 1           p          4.51         x           h         o
# 2           e          6.94         f           s         b
# 3           e          3.88         f           y         g
# 4           e          5.85         x           l         w
# ...       ...           ...       ...         ...       ...
# 3116940     e          9.29         f         NaN         n
# 3116941     e         10.88         s         NaN         w
# 3116942     p          7.82         x           e         e
# 3116943     e          9.45         p           i         n
# 3116944     p          3.20         x           s         g
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# id
# 0                          f               a            c          w
# 1                          f               a            c          n
# ...

# %% [markdown]
# <div style="padding: 15px;background-color:#99CCCC;font-size:100%;text-align:left;color:#0000cc">
#     <h2><span style='color:#85BB65'></span> Understanding Features:</h2>
#     <ul>
#     <li><strong>Class:</strong> Class Indicates whether the mushroom is edible (e) or poisonous (p).</li>
#     <br>
#     <li><strong>Cap_Diameter</strong>: It is the measured size of the mushroom cap.</li>
#     <br>
#     <li><strong>Cap_Shape</strong>: The shape of the mushroom cap.</li>
#     <br>
#     <li><strong>Cap_Surface</strong>: The surface texture of the mushroom cap.</li>
#     <br>
#     <li><strong>Cap_Color</strong>: The color of the mushroom cap.</li>
#     <br>
#     <li><strong>Does_Bruise_or_Bleed</strong>: Indicates whether the mushroom bruises or bleeds.</li>
#     <br>
#     <li><strong>Gill_Attachment</strong>: How the gills are attached to the mushroom stem.</li>
#     <br>
#     <li><strong>Gill_Spacing</strong>: The spacing between the gills.</li>
#     <br>
#     <li><strong>Gill_Color</strong>: The color of the mushroom gills.</li>
#     <br>
#     <li><strong>Stem_Height</strong>: The height of the mushroom stem.</li>
#     <br>
#     <li><strong>Stem_Width</strong>: The width of the mushroom stem.</li>
#     <br>
#     <li><strong>Stem_Root</strong>: The type of root the mushroom has.</li>
#     <br>
#     <li><strong>Stem_Surface</strong>: The surface texture of the mushroom stem.</li>
#     <br>
#     <li><strong>Stem_Color</strong>:The color of the mushroom stem.</li>
#     <br>
#     <li><strong>Veil_Type</strong>: The type of veil the mushroom has.</li>
#     <br>
#     <li><strong>Veil_Color</strong>: The color of the mushroom veil.</li>
#     <br>
#     <li><strong>Has_Ring</strong>: Indicates whether the mushroom has a ring.</li>
#     <br>
#     <li><strong>Ring_Type</strong>: The type of ring the mushroom has.</li>
#     <br>
#     <li><strong>Spore_Print_Color</strong>: The color of the mushroom's spore print.</li>
#     <br>
#     <li><strong>Habitat</strong>: The type of habitat where the mushroom is found.</li>
#     <br>
#     <li><strong>Season</strong>: The season during which the mushroom is found.</li>
#     </ul>
# </div>

# %% [markdown]
# # <center><div style="font-family: 'Roboto', sans-serif;"> 📊 Exploratory data analysis 📈 </div></center>

# %%
df_train
# Out:
#         class  cap-diameter cap-shape cap-surface cap-color  \
# id
# 0           e          8.80         f           s         u
# 1           p          4.51         x           h         o
# 2           e          6.94         f           s         b
# 3           e          3.88         f           y         g
# 4           e          5.85         x           l         w
# ...       ...           ...       ...         ...       ...
# 3116940     e          9.29         f         NaN         n
# 3116941     e         10.88         s         NaN         w
# 3116942     p          7.82         x           e         e
# 3116943     e          9.45         p           i         n
# 3116944     p          3.20         x           s         g
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# id
# 0                          f               a            c          w
# 1                          f               a            c          n
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3116945 entries, 0 to 3116944
# Data columns (total 21 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   class                 object
#  1   cap-diameter          float64
#  2   cap-shape             object
#  3   cap-surface           object
#  4   cap-color             object
#  5   does-bruise-or-bleed  object
#  6   gill-attachment       object
#  7   gill-spacing          object
#  8   gill-color            object
#  9   stem-height           float64
#  10  stem-width            float64
#  11  stem-root             object
#  12  stem-surface          object
#  13  stem-color            object
#  14  veil-type             object
#  15  veil-color            object
#  16  has-ring              object
#  17  ring-type             object
#  18  spore-print-color     object
#  19  habitat               object
#  20  season                object
# dtypes: float64(3), object(18)
# ...

# %%
unique_values = df_train.nunique()
data_types = df_train.dtypes
missing_values = df_train.isnull().sum()
summary_df = pd.DataFrame({
    'Data Types': data_types,
    'Unique Values': unique_values,
    'Null Values': missing_values,
})
summary_df = pd.concat([ summary_df])
print(summary_df)
# Out:
#                      Data Types  Unique Values  Null Values
# class                    object              2            0
# cap-diameter            float64           3913            4
# cap-shape                object             74           40
# cap-surface              object             83       671023
# cap-color                object             78           12
# does-bruise-or-bleed     object             26            8
# gill-attachment          object             78       523936
# gill-spacing             object             48      1258435
# gill-color               object             63           57
# stem-height             float64           2749            0
# stem-width              float64           5836            0
# stem-root                object             38      2757023
# stem-surface             object             60      1980861
# stem-color               object             59           38
# veil-type                object             22      2957493
# ...

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_test = pd.read_csv("/kaggle/input/playground-series-s4e8/test.csv", index_col = 'id')
df_test
# Out:
#          cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# id
# 3116945          8.64         x         NaN         n                    t
# 3116946          6.90         o           t         o                    f
# 3116947          2.00         b           g         n                    f
# 3116948          3.47         x           t         n                    f
# 3116949          6.17         x           h         y                    f
# ...               ...       ...         ...       ...                  ...
# 5194904          0.88         x           g         w                    f
# 5194905          3.12         x           s         w                    f
# 5194906          5.73         x           e         e                    f
# 5194907          5.03         b           g         n                    f
# 5194908         15.51         f         NaN         w                    f
#
# ...

# %%
unique_values = df_test.nunique()
data_types = df_test.dtypes
missing_values = df_test.isnull().sum()
summary_df = pd.DataFrame({
    'Data Types': data_types,
    'Unique Values': unique_values,
    'Null Values': missing_values,
})
summary_df = pd.concat([summary_df])
print(summary_df)
# Out:
#                      Data Types  Unique Values  Null Values
# cap-diameter            float64           3745            7
# cap-shape                object             62           31
# cap-surface              object             59       446904
# cap-color                object             57           13
# does-bruise-or-bleed     object             22           10
# gill-attachment          object             66       349821
# gill-spacing             object             35       839595
# gill-color               object             56           49
# stem-height             float64           2664            1
# stem-width              float64           5610            0
# stem-root                object             31      1838012
# stem-surface             object             54      1321488
# stem-color               object             55           21
# veil-type                object             15      1971545
# veil-color               object             23      1826124
# ...

# %%
df_test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div id = 'h1'  class = 'alert alert-block alert-info' style=" 5px solid #f0ad4e; background-color: #00FFFF; padding: 10px;">
# <h2>Data Cleaning</h2>
# </div>

# %%
new_columns = {'class': 'class','cap-diameter':'cap_diameter','cap-shape':'cap_shape','cap-surface':'cap_surface',
             'cap-color':'cap_color','does-bruise-or-bleed':'does_bruise_or_bleed','gill-attachment':'gill_attachment',
            'gill-spacing':'gill_spacing','gill-color':'gill_color','stem-height':'stem_height','stem-width':'stem_width',
            'stem-root':'stem_root','stem-surface':'stem_surface','stem-color':'stem_color','veil-type':'veil_type',
            'veil-color':'veil_color','has-ring':'has_ring','ring-type':'ring_type','spore-print-color':'spore_print_color',
            'habitat':'habitat','season':'season'}
df_train.rename(columns = new_columns, inplace = True)
df_train.columns
# Out:
# Index(['class', 'cap_diameter', 'cap_shape', 'cap_surface', 'cap_color',
#        'does_bruise_or_bleed', 'gill_attachment', 'gill_spacing', 'gill_color',
#        'stem_height', 'stem_width', 'stem_root', 'stem_surface', 'stem_color',
#        'veil_type', 'veil_color', 'has_ring', 'ring_type', 'spore_print_color',
#        'habitat', 'season'],
#       dtype='object')

# %%
new_columns = {'class': 'class','cap-diameter':'cap_diameter','cap-shape':'cap_shape','cap-surface':'cap_surface',
             'cap-color':'cap_color','does-bruise-or-bleed':'does_bruise_or_bleed','gill-attachment':'gill_attachment',
            'gill-spacing':'gill_spacing','gill-color':'gill_color','stem-height':'stem_height','stem-width':'stem_width',
            'stem-root':'stem_root','stem-surface':'stem_surface','stem-color':'stem_color','veil-type':'veil_type',
            'veil-color':'veil_color','has-ring':'has_ring','spore-print-color':'spore_print_color','habitat':'habitat','season':'season'}
df_test.rename(columns = new_columns, inplace = True )
df_test.columns
# Out:
# Index(['cap_diameter', 'cap_shape', 'cap_surface', 'cap_color',
#        'does_bruise_or_bleed', 'gill_attachment', 'gill_spacing', 'gill_color',
#        'stem_height', 'stem_width', 'stem_root', 'stem_surface', 'stem_color',
#        'veil_type', 'veil_color', 'has_ring', 'ring-type', 'spore_print_color',
#        'habitat', 'season'],
#       dtype='object')

# %%
for column in df_train.columns:
    unique_values = df_train[column].unique()
    print(f"Unique values in column '{column}': {unique_values}")
    print('---------------')
# Out:
# Unique values in column 'class': ['e' 'p']
# ---------------
# Unique values in column 'cap_diameter': [ 8.8   4.51  6.94 ... 38.11 55.63 54.07]
# ---------------
# Unique values in column 'cap_shape': ['f' 'x' 'p' 'b' 'o' 'c' 's' 'd' 'e' 'n' nan 'w' 'k' 'l' '19.29' '5 f' 't'
#  'g' 'z' 'a' '2.85' '7 x' 'r' 'u' '3.55' 'is s' 'y' '4.22' '3.6' '21.56'
#  'i' '6 x' '24.16' '8' 'm' 'ring-type' '10.13' 'is p' '7.43' 'h' '0.82'
#  '10.46' '2.77' '2.94' '12.62' '5.15' '19.04' '4.97' '49.21' 'b f' '9.13'
#  '1.66' '3.37' '7.21' '3.25' '11.12' '3 x' '4.3' '7.41' '6.21' '8.29'
#  '54.78' '20.25' '3.52' '3.04' '2.63' '3.91' '6.44' '8.3' '7.6' '17.44'
#  '4.33' '2.82' '6.53' '19.06']
# ---------------
# Unique values in column 'cap_surface': ['s' 'h' 'y' 'l' 't' 'e' 'g' nan 'd' 'i' 'w' 'k' '15.94' 'f' 'n' 'r' 'o'
#  'a' 'u' 'z' '2.7' 'does l' '5.07' 'p' 'b' 'm' 'cap-diameter' '1.43' 'x'
#  '7.14' 'c' 'is h' 'does t' '0.85' '6.57' '12.79' '6.45' '4.66' '23.18'
# ...

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px;color:#0000cc;'>
#     <b><h2><span>|</span>Insights</h2></b><br>
#     <li> We observe that most features in this dataset are of object data type, indicating a high number of categorical variables.</li>
#     <li> In categorical variables, some values are misplaced as floats, and other names are incorrectly mentioned.</li>
#     <li> Available as null values in this dataset.</li>
#     <li> There are no duplicate values in this dataset.</li>
# </div>

# %% [markdown]
# <div id = 'h1'  class = 'alert alert-block alert-info' style=" 5px solid #f0ad4e; background-color: #00FFFF; padding: 10px;">
# <h4> Count the missplaced values </h4>
# </div>

# %%
for col in df_train.columns:
    if df_train[col].dtype == 'object':
        non_alpha_values = df_train[col].dropna().apply(lambda x: not x.isalpha()).sum()
        misplaced_values = df_train[col].dropna().apply(lambda x: x if not x.isalpha() else None).dropna().unique()
        
        print(f"Number of misplaced values in '{col}': {non_alpha_values}")
#         if non_alpha_values > 0:
#             print(f"Misplaced values in '{col}': {misplaced_values}")
# Out:
# Number of misplaced values in 'class': 0
# Number of misplaced values in 'cap_shape': 55
# Number of misplaced values in 'cap_surface': 64
# Number of misplaced values in 'cap_color': 61
# Number of misplaced values in 'does_bruise_or_bleed': 4
# Number of misplaced values in 'gill_attachment': 54
# Number of misplaced values in 'gill_spacing': 30
# Number of misplaced values in 'gill_color': 47
# Number of misplaced values in 'stem_root': 15
# Number of misplaced values in 'stem_surface': 40
# Number of misplaced values in 'stem_color': 38
# Number of misplaced values in 'veil_type': 3
# Number of misplaced values in 'veil_color': 3
# Number of misplaced values in 'has_ring': 2
# Number of misplaced values in 'ring_type': 22
# Number of misplaced values in 'spore_print_color': 9
# Number of misplaced values in 'habitat': 30
# Number of misplaced values in 'season': 0

# %% [markdown]
# <div id = 'h3'  class = 'alert alert-block alert-info' style=" 5px solid #f0ad4e; background-color: #00FFFF; padding: 10px;">
# <h4> Count the less than 100 values  in each column </h4>
# </div>

# %%
df_count = df_train.copy()
cat_cols = df_count.select_dtypes(include=['object']).columns
number_of_count = 100
for col in cat_cols:
    value_counts = df_count[col].value_counts()
    rare_values = value_counts[value_counts < number_of_count].index
    rare_count = len(rare_values)
    print(f" {col}- Number of rare values: {rare_count}")
# Out:
#  class- Number of rare values: 0
#  cap_shape- Number of rare values: 67
#  cap_surface- Number of rare values: 72
#  cap_color- Number of rare values: 66
#  does_bruise_or_bleed- Number of rare values: 24
#  gill_attachment- Number of rare values: 71
#  gill_spacing- Number of rare values: 45
#  gill_color- Number of rare values: 51
#  stem_root- Number of rare values: 33
#  stem_surface- Number of rare values: 52
#  stem_color- Number of rare values: 46
#  veil_type- Number of rare values: 21
#  veil_color- Number of rare values: 18
#  has_ring- Number of rare values: 21
#  ring_type- Number of rare values: 32
#  spore_print_color- Number of rare values: 25
#  habitat- Number of rare values: 44
#  season- Number of rare values: 0

# %% [markdown]
# <div id = 'h3'  class = 'alert alert-block alert-info' style=" 5px solid #f0ad4e; background-color: #00FFFF; padding: 10px;">
# <h4> Replace the float values that are not present in the orginal data description with nan values </h4>
# </div>

# %%
alphabet_set = set('abcdefghijklmnopqrstuvwxyz')

for col in df_train.select_dtypes(include=['object']).columns:
    valid_mask = [isinstance(x, str) and len(x) == 1 and x in alphabet_set for x in df_train[col]]
    df_train[col] = np.where(valid_mask, df_train[col], np.nan)
df_train
# Out:
#         class  cap_diameter cap_shape cap_surface cap_color  \
# id
# 0           e          8.80         f           s         u
# 1           p          4.51         x           h         o
# 2           e          6.94         f           s         b
# 3           e          3.88         f           y         g
# 4           e          5.85         x           l         w
# ...       ...           ...       ...         ...       ...
# 3116940     e          9.29         f         NaN         n
# 3116941     e         10.88         s         NaN         w
# 3116942     p          7.82         x           e         e
# 3116943     e          9.45         p           i         n
# 3116944     p          3.20         x           s         g
#
#         does_bruise_or_bleed gill_attachment gill_spacing gill_color  \
# id
# 0                          f               a            c          w
# 1                          f               a            c          n
# ...

# %%
df_train.isnull().sum()
# Out:
# class                         0
# cap_diameter                  4
# cap_shape                    95
# cap_surface              671096
# cap_color                    84
# does_bruise_or_bleed         12
# gill_attachment          523996
# gill_spacing            1258466
# gill_color                  124
# stem_height                   0
# stem_width                    0
# stem_root               2757038
# stem_surface            1980908
# stem_color                   78
# veil_type               2957496
# veil_color              2740950
# has_ring                     26
# ring_type                128907
# spore_print_color       2849693
# habitat                      83
# season                        0
# dtype: int64

# %%
df_train
# Out:
#         class  cap_diameter cap_shape cap_surface cap_color  \
# id
# 0           e          8.80         f           s         u
# 1           p          4.51         x           h         o
# 2           e          6.94         f           s         b
# 3           e          3.88         f           y         g
# 4           e          5.85         x           l         w
# ...       ...           ...       ...         ...       ...
# 3116940     e          9.29         f         NaN         n
# 3116941     e         10.88         s         NaN         w
# 3116942     p          7.82         x           e         e
# 3116943     e          9.45         p           i         n
# 3116944     p          3.20         x           s         g
#
#         does_bruise_or_bleed gill_attachment gill_spacing gill_color  \
# id
# 0                          f               a            c          w
# 1                          f               a            c          n
# ...

# %%
columns = ['class','cap_shape', 'cap_surface', 'cap_color', 'does_bruise_or_bleed',
    'gill_attachment', 'gill_spacing', 'gill_color', 'stem_root',
    'stem_surface', 'stem_color', 'veil_type', 'veil_color', 'has_ring',
    'ring_type', 'spore_print_color', 'habitat', 'season'
]
n_cols = 3
n_rows = (len(columns) + n_cols - 1) // n_cols
fig, axes = plt.subplots(n_rows, n_cols, figsize=(40, n_rows * 10))
axes = axes.flatten()
for i, column in enumerate(columns):
    ax = sns.countplot(data=df_train, x=column, ax=axes[i])
    ax.set_title(f'Count Plot for {column}')
    for container in ax.containers:
        ax.bar_label(container)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# <div id = 'h1'  class = 'alert alert-block alert-info' style=" 5px solid #f0ad4e; background-color: #00FFFF; padding: 10px;">
# <h2> Calculate the percentage of the null values </h2>
# </div>

# %%
null_percentage = (df_train.isnull().sum() / len(df_train)) * 100
null_percentage_df = pd.DataFrame(null_percentage, columns=['Null Percentage'])
n_miss = df_train.isnull().sum()
missing_df = pd.DataFrame({'n_miss': n_miss, 'Null Percentage': null_percentage})
missing_df = missing_df.sort_values(by='n_miss', ascending=False)
print(missing_df)
# Out:
#                        n_miss  Null Percentage
# veil_type             2957496        94.884446
# spore_print_color     2849693        91.425835
# stem_root             2757038        88.453213
# veil_color            2740950        87.937067
# stem_surface          1980908        63.552870
# gill_spacing          1258466        40.374983
# cap_surface            671096        21.530569
# gill_attachment        523996        16.811205
# ring_type              128907         4.135684
# gill_color                124         0.003978
# cap_shape                  95         0.003048
# cap_color                  84         0.002695
# habitat                    83         0.002663
# stem_color                 78         0.002502
# has_ring                   26         0.000834
# does_bruise_or_bleed       12         0.000385
# cap_diameter                4         0.000128
# class                       0         0.000000
# stem_width                  0         0.000000
# ...

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px;color:#0000cc;'>
# <li>In this dataset, the columns 'veil_type', 'spore_print_color', 'stem_root', and 'veil_color' each have over 80% null values, so we will drop these columns.</li>

# %%
df_train.drop(['veil_type','spore_print_color','stem_root','veil_color'], axis =1, inplace = True)

# %%
df_train
# Out:
#         class  cap_diameter cap_shape cap_surface cap_color  \
# id
# 0           e          8.80         f           s         u
# 1           p          4.51         x           h         o
# 2           e          6.94         f           s         b
# 3           e          3.88         f           y         g
# 4           e          5.85         x           l         w
# ...       ...           ...       ...         ...       ...
# 3116940     e          9.29         f         NaN         n
# 3116941     e         10.88         s         NaN         w
# 3116942     p          7.82         x           e         e
# 3116943     e          9.45         p           i         n
# 3116944     p          3.20         x           s         g
#
#         does_bruise_or_bleed gill_attachment gill_spacing gill_color  \
# id
# 0                          f               a            c          w
# 1                          f               a            c          n
# ...

# %% [markdown]
# <div id = 'h1'  class = 'alert alert-block alert-info' style=" 5px solid #f0ad4e; background-color: #00FFFF; padding: 10px;">
# <h2> Check the outliers in numerical variables </h2>
# </div>

# %%
# columns = ['cap_diameter','stem_height','stem_width']
# for column in columns:
#     ax = sns.scatterplot(data = df_train, x = 'cap_shape', y = column, hue = 'class' )
#     plt.show()

# %%
columns = ['stem_height','stem_width']
for column in columns:
    ax = sns.scatterplot(data = df_train, x = 'cap_diameter', y = column, hue = 'class',palette='viridis' )
    plt.show()

# %%
df_train['cap_diameter'].max()
# Out:
# 80.67

# %%
col_name = ['cap_diameter', 'stem_height', 'stem_width']

def outlier_thresholds(df_train, col_name, q1=0.01, q3=0.99):
    quartile1 = df_train[col_name].quantile(q1)
    quartile3 = df_train[col_name].quantile(q3)
    interquantile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquantile_range
    low_limit = quartile1 - 1.5 * interquantile_range
    return low_limit, up_limit

def check_outlier(df_train, col_name):
    low_limit, up_limit = outlier_thresholds(df_train, col_name)
    if df_train[(df_train[col_name] > up_limit) | (df_train[col_name] < low_limit)].any(axis=None):
        return True
    else:
        return False
    
def replace_with_thresholds(df_train, variable):
    low_limit, up_limit = outlier_thresholds(df_train, variable)
    df_train.loc[(df_train[variable] < low_limit), variable] = low_limit
    df_train.loc[(df_train[variable] > up_limit), variable] = up_limit

# %%
columns = ['cap_diameter','stem_height','stem_width']
sns.pairplot(df_train, vars = columns, hue = 'class')
plt.show()

# %% [markdown]
# <div id = 'h1'  class = 'alert alert-block alert-info' style=" 5px solid #f0ad4e; background-color: #00FFFF; padding: 10px;">
# <h2> Fill the null values </h2>
# </div>

# %%
from sklearn.impute import SimpleImputer

filled_df = df_train.copy()
num_cols = filled_df.select_dtypes(include=['number']).columns
cat_cols = filled_df.select_dtypes(include=['object']).columns

numeric_imputer = SimpleImputer(strategy='median') 
filled_df[num_cols] = numeric_imputer.fit_transform(filled_df[num_cols])

categorical_imputer = SimpleImputer(strategy='most_frequent')
filled_df[cat_cols] = categorical_imputer.fit_transform(filled_df[cat_cols])

# %%
filled_df.isnull().sum()
# Out:
# class                   0
# cap_diameter            0
# cap_shape               0
# cap_surface             0
# cap_color               0
# does_bruise_or_bleed    0
# gill_attachment         0
# gill_spacing            0
# gill_color              0
# stem_height             0
# stem_width              0
# stem_surface            0
# stem_color              0
# has_ring                0
# ring_type               0
# habitat                 0
# season                  0
# dtype: int64

# %%
def stacked_countplots_with_target(filled_df, target_column):
    # Get categorical columns excluding the target column
    cat_cols = filled_df.select_dtypes(include=['object']).columns
    if target_column in cat_cols:
        cat_cols = cat_cols.drop(target_column)

    # Set up the matplotlib figure
    plt.figure(figsize=(10, 5 * len(cat_cols)))
    
    for i, col in enumerate(cat_cols):
        plt.subplot(len(cat_cols), 1, i + 1)
        sns.countplot(data=filled_df, x=col, hue=target_column,palette='viridis',order=filled_df[col].value_counts().index)
        plt.title(f'Count Plot of {col} by {target_column}')
        plt.xlabel(col)
        plt.ylabel('Count')
    
    plt.tight_layout()
    plt.show()


# Call the function with the DataFrame and target column 'class'
stacked_countplots_with_target(filled_df, 'class')

# %% [markdown]
# <div id = 'h1'  class = 'alert alert-block alert-info' style=" 5px solid #f0ad4e; background-color: #00FFFF; padding: 10px;">
# <h3> Encoding </h3>
# </div>

# %%
from sklearn import preprocessing
non_numeric_columns = df_train.select_dtypes(include=['object']).columns
label_encoder = preprocessing.LabelEncoder()

for column in non_numeric_columns:
    df_train[column] = label_encoder.fit_transform(df_train[column])

# %%
df_train.head()
# Out:
#     class  cap_diameter  cap_shape  cap_surface  cap_color  \
# id
# 0       0          8.80          5           16         18
# 1       1          4.51         20            7         13
# 2       0          6.94          5           16          1
# 3       0          3.88          5           21          6
# 4       0          5.85         20           10         19
#
#     does_bruise_or_bleed  gill_attachment  gill_spacing  gill_color  \
# id
# 0                      5                0             2          19
# 1                      5                0             2          12
# 2                      5               20             2          19
# 3                      5               16            19           6
# 4                      5                3            19          19
#
#     stem_height  stem_width  stem_surface  stem_color  has_ring  ring_type  \
# id
# 0          4.51       15.39            23          19         4          5
# ...

# %% [markdown]
#  apply the lble encode to change the catagerical columes into numeric

# %% [markdown]
# <div style = 'border:3px solid brown;background-color:lightyellow;padding:10px;color:#0000cc;'>
# <li>Apply label encoding to convert the categorical columns into numeric values..</li>
