# %%
import os
import numpy as np
import pandas as pd
import time
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder
from sklearn.metrics import matthews_corrcoef, make_scorer
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings('ignore')

# Custom print function for logging in Kaggle
__print__ = print
def print(string):
    os.system(f'echo \"{string}\"')
    __print__(string)

# Custom MCC metric function for XGBoost
def mcc_eval_metric(preds, dtrain):
    labels = dtrain.get_label()
    preds = (preds > 0.5).astype(int)
    mcc = matthews_corrcoef(labels, preds)
    return 'mcc', mcc

# Load the datasets
print('1/7: Loading datasets...')
df_sub = pd.read_csv('/kaggle/input/playground-series-s4e8/sample_submission.csv')
df_train = pd.read_csv('/kaggle/input/playground-series-s4e8/train.csv')
df_test = pd.read_csv('/kaggle/input/playground-series-s4e8/test.csv')
print('1/7: Datasets loaded successfully.\n')

# Drop 'id' column
df_train = df_train.drop(columns=['id'])
df_test = df_test.drop(columns=['id'])

# Encode categorical variables
print('2/7: Encoding categorical variables...')
cat_cols_train = df_train.select_dtypes(include=['object']).columns
cat_cols_train = cat_cols_train[cat_cols_train != 'class']

ordinal_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
df_train[cat_cols_train] = ordinal_encoder.fit_transform(df_train[cat_cols_train].astype(str))
df_test[cat_cols_train] = ordinal_encoder.transform(df_test[cat_cols_train].astype(str))

le = LabelEncoder()
df_train['class'] = le.fit_transform(df_train['class'])
print('2/7: Categorical variables encoded.\n')

# Split data into features and target
X = df_train.drop(['class'], axis=1)
y = df_train['class']

# Sampling data for hyperparameter tuning
print('3/7: Sampling data for hyperparameter tuning...')
sample_size = 100000  # sample size for tuning
X_sample, _, y_sample, _ = train_test_split(X, y, train_size=sample_size, stratify=y, random_state=42)
print(f'3/7: Sampled {sample_size} records for hyperparameter tuning.\n')

# Split sampled data into training and validation sets
print('4/7: Splitting sampled data into training and validation sets...')
train_X_sample, val_X_sample, train_y_sample, val_y_sample = train_test_split(X_sample, y_sample, test_size=0.2, random_state=42, stratify=y_sample)
print('4/7: Data splitting completed.\n')

# Define the base model with GPU support
base_model = XGBClassifier(
    objective='binary:logistic',  # Ensure it's a binary classification
    tree_method='hist',       # Use GPU for training
    random_state=42
)

# Custom scorer
mcc_scorer = make_scorer(matthews_corrcoef)

# Declare params
print('5/7: Declare params...')
params = {'colsample_bytree': 0.6, 'max_depth': 14, 'min_child_weight': 7, 'n_estimators': 100}
print(f'5/7: Declare params completed.\n')

# Train the best model on the entire training data
print('6/7: Training the best model on full dataset...')
start_time = time.time()
eval_set = [(train_X_sample, train_y_sample), (val_X_sample, val_y_sample)]
best_model = XGBClassifier(
    objective='binary:logistic',
    tree_method='hist',
    colsample_bytree=params['colsample_bytree'],
    max_depth=params['max_depth'],
    min_child_weight=params['min_child_weight'],
    n_estimators=params['n_estimators'],
    random_state=42
)
best_model.fit(X, y, eval_metric=mcc_eval_metric, eval_set=eval_set, verbose=True)
end_time = time.time()
print(f'6/7: Model training completed in {end_time - start_time:.2f} seconds.\n')

# Predict on test set
print('7/7: Making predictions on test set...')
test_preds = best_model.predict(df_test)

# Ensure predictions are in correct format
test_preds = test_preds.astype(int)

# Map predictions back to original labels
test_pred_class = le.inverse_transform(test_preds)

# Align predictions with sample submission format
df_sub['class'] = test_pred_class

# Check the final submission data
print('Submission data sample after mapping:')
print(df_sub.head())

# Save predictions
print('7/7: Saving predictions to submission.csv...')
df_sub.to_csv('submission.csv', index=False)
print('7/7: Predictions saved successfully to submission.csv.')

# Read the saved submission file to verify
submission = pd.read_csv('submission.csv')
print('Saved submission file sample:')
print(submission.head())
# Out:
# 1/7: Loading datasets...
# 1/7: Loading datasets...
# 1/7: Datasets loaded successfully.
#
# 1/7: Datasets loaded successfully.
#
# 2/7: Encoding categorical variables...
# 2/7: Encoding categorical variables...
# 2/7: Categorical variables encoded.
#
# 2/7: Categorical variables encoded.
#
# 3/7: Sampling data for hyperparameter tuning...
# 3/7: Sampling data for hyperparameter tuning...
# 3/7: Sampled 100000 records for hyperparameter tuning.
#
# 3/7: Sampled 100000 records for hyperparameter tuning.
#
# 4/7: Splitting sampled data into training and validation sets...
# 4/7: Splitting sampled data into training and validation sets...
# 4/7: Data splitting completed.
#
# 4/7: Data splitting completed.
#
# 5/7: Declare params...
# 5/7: Declare params...
# 5/7: Declare params completed.
#
# 5/7: Declare params completed.
#
# 6/7: Training the best model on full dataset...
# 6/7: Training the best model on full dataset...
# [0]	validation_0-logloss:0.47184	validation_0-mcc:0.90167	validation_1-logloss:0.47022	validation_1-mcc:0.90778
# [1]	validation_0-logloss:0.33915	validation_0-mcc:0.96256	validation_1-logloss:0.33694	validation_1-mcc:0.96743
# [2]	validation_0-logloss:0.25534	validation_0-mcc:0.96840	validation_1-logloss:0.25263	validation_1-mcc:0.97252
# [3]	validation_0-logloss:0.20308	validation_0-mcc:0.97261	validation_1-logloss:0.20031	validation_1-mcc:0.97523
# [4]	validation_0-logloss:0.15926	validation_0-mcc:0.97540	validation_1-logloss:0.15651	validation_1-mcc:0.97795
# [5]	validation_0-logloss:0.12722	validation_0-mcc:0.97736	validation_1-logloss:0.12465	validation_1-mcc:0.97954
# [6]	validation_0-logloss:0.10451	validation_0-mcc:0.97867	validation_1-logloss:0.10208	validation_1-mcc:0.98075
# [7]	validation_0-logloss:0.08737	validation_0-mcc:0.97970	validation_1-logloss:0.08520	validation_1-mcc:0.98155
# [8]	validation_0-logloss:0.07410	validation_0-mcc:0.98035	validation_1-logloss:0.07193	validation_1-mcc:0.98256
# [9]	validation_0-logloss:0.06627	validation_0-mcc:0.98070	validation_1-logloss:0.06412	validation_1-mcc:0.98206
# [10]	validation_0-logloss:0.05854	validation_0-mcc:0.98105	validation_1-logloss:0.05637	validation_1-mcc:0.98266
# [11]	validation_0-logloss:0.05423	validation_0-mcc:0.98125	validation_1-logloss:0.05212	validation_1-mcc:0.98256
# [12]	validation_0-logloss:0.05017	validation_0-mcc:0.98166	validation_1-logloss:0.04802	validation_1-mcc:0.98266
# [13]	validation_0-logloss:0.04715	validation_0-mcc:0.98183	validation_1-logloss:0.04514	validation_1-mcc:0.98296
# [14]	validation_0-logloss:0.04456	validation_0-mcc:0.98221	validation_1-logloss:0.04260	validation_1-mcc:0.98357
# [15]	validation_0-logloss:0.04276	validation_0-mcc:0.98228	validation_1-logloss:0.04091	validation_1-mcc:0.98367
# [16]	validation_0-logloss:0.04124	validation_0-mcc:0.98264	validation_1-logloss:0.03944	validation_1-mcc:0.98407
# [17]	validation_0-logloss:0.04049	validation_0-mcc:0.98271	validation_1-logloss:0.03871	validation_1-mcc:0.98437
# [18]	validation_0-logloss:0.03975	validation_0-mcc:0.98284	validation_1-logloss:0.03803	validation_1-mcc:0.98387
# [19]	validation_0-logloss:0.03890	validation_0-mcc:0.98294	validation_1-logloss:0.03728	validation_1-mcc:0.98417
# [20]	validation_0-logloss:0.03804	validation_0-mcc:0.98326	validation_1-logloss:0.03650	validation_1-mcc:0.98477
# [21]	validation_0-logloss:0.03746	validation_0-mcc:0.98336	validation_1-logloss:0.03585	validation_1-mcc:0.98507
# [22]	validation_0-logloss:0.03711	validation_0-mcc:0.98351	validation_1-logloss:0.03555	validation_1-mcc:0.98497
# [23]	validation_0-logloss:0.03644	validation_0-mcc:0.98379	validation_1-logloss:0.03489	validation_1-mcc:0.98477
# [24]	validation_0-logloss:0.03609	validation_0-mcc:0.98399	validation_1-logloss:0.03472	validation_1-mcc:0.98477
# [25]	validation_0-logloss:0.03581	validation_0-mcc:0.98404	validation_1-logloss:0.03446	validation_1-mcc:0.98477
# [26]	validation_0-logloss:0.03538	validation_0-mcc:0.98419	validation_1-logloss:0.03404	validation_1-mcc:0.98497
# [27]	validation_0-logloss:0.03480	validation_0-mcc:0.98437	validation_1-logloss:0.03357	validation_1-mcc:0.98507
# [28]	validation_0-logloss:0.03443	validation_0-mcc:0.98455	validation_1-logloss:0.03316	validation_1-mcc:0.98538
# [29]	validation_0-logloss:0.03418	validation_0-mcc:0.98462	validation_1-logloss:0.03295	validation_1-mcc:0.98517
# [30]	validation_0-logloss:0.03400	validation_0-mcc:0.98472	validation_1-logloss:0.03286	validation_1-mcc:0.98537
# [31]	validation_0-logloss:0.03380	validation_0-mcc:0.98482	validation_1-logloss:0.03278	validation_1-mcc:0.98547
# [32]	validation_0-logloss:0.03373	validation_0-mcc:0.98482	validation_1-logloss:0.03271	validation_1-mcc:0.98547
# [33]	validation_0-logloss:0.03352	validation_0-mcc:0.98490	validation_1-logloss:0.03257	validation_1-mcc:0.98527
# [34]	validation_0-logloss:0.03342	validation_0-mcc:0.98495	validation_1-logloss:0.03247	validation_1-mcc:0.98527
# [35]	validation_0-logloss:0.03327	validation_0-mcc:0.98497	validation_1-logloss:0.03233	validation_1-mcc:0.98517
# [36]	validation_0-logloss:0.03314	validation_0-mcc:0.98495	validation_1-logloss:0.03223	validation_1-mcc:0.98517
# [37]	validation_0-logloss:0.03300	validation_0-mcc:0.98495	validation_1-logloss:0.03205	validation_1-mcc:0.98537
# [38]	validation_0-logloss:0.03287	validation_0-mcc:0.98497	validation_1-logloss:0.03189	validation_1-mcc:0.98557
# [39]	validation_0-logloss:0.03275	validation_0-mcc:0.98508	validation_1-logloss:0.03184	validation_1-mcc:0.98547
# [40]	validation_0-logloss:0.03270	validation_0-mcc:0.98502	validation_1-logloss:0.03177	validation_1-mcc:0.98547
# [41]	validation_0-logloss:0.03259	validation_0-mcc:0.98515	validation_1-logloss:0.03168	validation_1-mcc:0.98557
# [42]	validation_0-logloss:0.03250	validation_0-mcc:0.98520	validation_1-logloss:0.03162	validation_1-mcc:0.98568
# [43]	validation_0-logloss:0.03247	validation_0-mcc:0.98523	validation_1-logloss:0.03158	validation_1-mcc:0.98568
# [44]	validation_0-logloss:0.03240	validation_0-mcc:0.98525	validation_1-logloss:0.03155	validation_1-mcc:0.98557
# [45]	validation_0-logloss:0.03232	validation_0-mcc:0.98520	validation_1-logloss:0.03148	validation_1-mcc:0.98547
# [46]	validation_0-logloss:0.03228	validation_0-mcc:0.98528	validation_1-logloss:0.03143	validation_1-mcc:0.98547
# [47]	validation_0-logloss:0.03217	validation_0-mcc:0.98545	validation_1-logloss:0.03119	validation_1-mcc:0.98547
# [48]	validation_0-logloss:0.03209	validation_0-mcc:0.98538	validation_1-logloss:0.03112	validation_1-mcc:0.98557
# [49]	validation_0-logloss:0.03201	validation_0-mcc:0.98548	validation_1-logloss:0.03108	validation_1-mcc:0.98557
# [50]	validation_0-logloss:0.03190	validation_0-mcc:0.98548	validation_1-logloss:0.03099	validation_1-mcc:0.98567
# [51]	validation_0-logloss:0.03186	validation_0-mcc:0.98550	validation_1-logloss:0.03095	validation_1-mcc:0.98578
# [52]	validation_0-logloss:0.03179	validation_0-mcc:0.98545	validation_1-logloss:0.03086	validation_1-mcc:0.98578
# [53]	validation_0-logloss:0.03172	validation_0-mcc:0.98550	validation_1-logloss:0.03076	validation_1-mcc:0.98598
# [54]	validation_0-logloss:0.03161	validation_0-mcc:0.98545	validation_1-logloss:0.03066	validation_1-mcc:0.98588
# [55]	validation_0-logloss:0.03155	validation_0-mcc:0.98558	validation_1-logloss:0.03057	validation_1-mcc:0.98588
# [56]	validation_0-logloss:0.03152	validation_0-mcc:0.98555	validation_1-logloss:0.03050	validation_1-mcc:0.98588
# [57]	validation_0-logloss:0.03146	validation_0-mcc:0.98558	validation_1-logloss:0.03046	validation_1-mcc:0.98588
# [58]	validation_0-logloss:0.03135	validation_0-mcc:0.98571	validation_1-logloss:0.03035	validation_1-mcc:0.98588
# [59]	validation_0-logloss:0.03129	validation_0-mcc:0.98571	validation_1-logloss:0.03035	validation_1-mcc:0.98588
# [60]	validation_0-logloss:0.03120	validation_0-mcc:0.98571	validation_1-logloss:0.03025	validation_1-mcc:0.98608
# [61]	validation_0-logloss:0.03117	validation_0-mcc:0.98565	validation_1-logloss:0.03023	validation_1-mcc:0.98608
# [62]	validation_0-logloss:0.03116	validation_0-mcc:0.98565	validation_1-logloss:0.03019	validation_1-mcc:0.98598
# [63]	validation_0-logloss:0.03108	validation_0-mcc:0.98568	validation_1-logloss:0.03012	validation_1-mcc:0.98598
# [64]	validation_0-logloss:0.03106	validation_0-mcc:0.98573	validation_1-logloss:0.03008	validation_1-mcc:0.98598
# [65]	validation_0-logloss:0.03099	validation_0-mcc:0.98575	validation_1-logloss:0.03002	validation_1-mcc:0.98598
# [66]	validation_0-logloss:0.03089	validation_0-mcc:0.98578	validation_1-logloss:0.02998	validation_1-mcc:0.98598
# [67]	validation_0-logloss:0.03081	validation_0-mcc:0.98583	validation_1-logloss:0.02993	validation_1-mcc:0.98598
# [68]	validation_0-logloss:0.03073	validation_0-mcc:0.98586	validation_1-logloss:0.02984	validation_1-mcc:0.98598
# [69]	validation_0-logloss:0.03065	validation_0-mcc:0.98593	validation_1-logloss:0.02978	validation_1-mcc:0.98598
# [70]	validation_0-logloss:0.03059	validation_0-mcc:0.98591	validation_1-logloss:0.02972	validation_1-mcc:0.98618
# [71]	validation_0-logloss:0.03049	validation_0-mcc:0.98593	validation_1-logloss:0.02960	validation_1-mcc:0.98618
# [72]	validation_0-logloss:0.03045	validation_0-mcc:0.98593	validation_1-logloss:0.02953	validation_1-mcc:0.98608
# [73]	validation_0-logloss:0.03040	validation_0-mcc:0.98596	validation_1-logloss:0.02952	validation_1-mcc:0.98608
# [74]	validation_0-logloss:0.03031	validation_0-mcc:0.98601	validation_1-logloss:0.02949	validation_1-mcc:0.98608
# [75]	validation_0-logloss:0.03024	validation_0-mcc:0.98603	validation_1-logloss:0.02947	validation_1-mcc:0.98628
# [76]	validation_0-logloss:0.03021	validation_0-mcc:0.98606	validation_1-logloss:0.02945	validation_1-mcc:0.98628
# [77]	validation_0-logloss:0.03016	validation_0-mcc:0.98603	validation_1-logloss:0.02945	validation_1-mcc:0.98618
# [78]	validation_0-logloss:0.03008	validation_0-mcc:0.98603	validation_1-logloss:0.02934	validation_1-mcc:0.98638
# [79]	validation_0-logloss:0.02998	validation_0-mcc:0.98596	validation_1-logloss:0.02925	validation_1-mcc:0.98638
# [80]	validation_0-logloss:0.02992	validation_0-mcc:0.98596	validation_1-logloss:0.02923	validation_1-mcc:0.98638
# [81]	validation_0-logloss:0.02986	validation_0-mcc:0.98601	validation_1-logloss:0.02912	validation_1-mcc:0.98648
# [82]	validation_0-logloss:0.02982	validation_0-mcc:0.98603	validation_1-logloss:0.02911	validation_1-mcc:0.98638
# [83]	validation_0-logloss:0.02980	validation_0-mcc:0.98603	validation_1-logloss:0.02911	validation_1-mcc:0.98638
# [84]	validation_0-logloss:0.02974	validation_0-mcc:0.98613	validation_1-logloss:0.02909	validation_1-mcc:0.98668
# [85]	validation_0-logloss:0.02972	validation_0-mcc:0.98613	validation_1-logloss:0.02910	validation_1-mcc:0.98658
# [86]	validation_0-logloss:0.02970	validation_0-mcc:0.98616	validation_1-logloss:0.02905	validation_1-mcc:0.98658
# [87]	validation_0-logloss:0.02967	validation_0-mcc:0.98616	validation_1-logloss:0.02904	validation_1-mcc:0.98658
# [88]	validation_0-logloss:0.02962	validation_0-mcc:0.98613	validation_1-logloss:0.02899	validation_1-mcc:0.98658
# [89]	validation_0-logloss:0.02956	validation_0-mcc:0.98621	validation_1-logloss:0.02886	validation_1-mcc:0.98668
# [90]	validation_0-logloss:0.02951	validation_0-mcc:0.98623	validation_1-logloss:0.02881	validation_1-mcc:0.98658
# [91]	validation_0-logloss:0.02947	validation_0-mcc:0.98628	validation_1-logloss:0.02881	validation_1-mcc:0.98668
# [92]	validation_0-logloss:0.02942	validation_0-mcc:0.98636	validation_1-logloss:0.02873	validation_1-mcc:0.98679
# [93]	validation_0-logloss:0.02939	validation_0-mcc:0.98638	validation_1-logloss:0.02867	validation_1-mcc:0.98679
# [94]	validation_0-logloss:0.02931	validation_0-mcc:0.98638	validation_1-logloss:0.02858	validation_1-mcc:0.98668
# [95]	validation_0-logloss:0.02926	validation_0-mcc:0.98643	validation_1-logloss:0.02854	validation_1-mcc:0.98668
# [96]	validation_0-logloss:0.02921	validation_0-mcc:0.98641	validation_1-logloss:0.02851	validation_1-mcc:0.98658
# [97]	validation_0-logloss:0.02913	validation_0-mcc:0.98649	validation_1-logloss:0.02846	validation_1-mcc:0.98658
# [98]	validation_0-logloss:0.02912	validation_0-mcc:0.98649	validation_1-logloss:0.02842	validation_1-mcc:0.98658
# [99]	validation_0-logloss:0.02909	validation_0-mcc:0.98649	validation_1-logloss:0.02839	validation_1-mcc:0.98658
# 6/7: Model training completed in 47.25 seconds.
#
# 6/7: Model training completed in 47.25 seconds.
#
# 7/7: Making predictions on test set...
# 7/7: Making predictions on test set...
# Submission data sample after mapping:
# Submission data sample after mapping:
#         id class
# 0  3116945     e
# 1  3116946     p
# 2  3116947     p
# 3  3116948     p
# 4  3116949     e
#         id class
# 0  3116945     e
# 1  3116946     p
# 2  3116947     p
# 3  3116948     p
# 4  3116949     e
# 7/7: Saving predictions to submission.csv...
# 7/7: Saving predictions to submission.csv...
# 7/7: Predictions saved successfully to submission.csv.
# 7/7: Predictions saved successfully to submission.csv.
# Saved submission file sample:
# Saved submission file sample:
#         id class
# 0  3116945     e
# 1  3116946     p
# 2  3116947     p
# 3  3116948     p
# 4  3116949     e
#         id class
# 0  3116945     e
# 1  3116946     p
# 2  3116947     p
# 3  3116948     p
# 4  3116949     e

# %% [markdown]
# ## Conclusion
# In this notebook, we successfully developed a model to classify mushrooms as edible or poisonous using the XGBoost algorithm. The model's performance was evaluated using the Matthews correlation coefficient (MCC), and the predictions were saved in the correct format for submission.
#
# By following this process, we ensured that the data was properly preprocessed, the model was accurately trained and evaluated, and the predictions were correctly formatted and saved.
#
# Thank you for following along with this notebook. If you found this helpful, please consider giving an upvote. Your support is greatly appreciated!
