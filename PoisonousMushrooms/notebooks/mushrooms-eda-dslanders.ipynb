# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv('/kaggle/input/playground-series-s4e8/train.csv').drop('id', axis=1)
label = df_train['class']
df_train = df_train.drop('class', axis=1)
df_train['class'] = label
df_train.head()
# Out:
#    cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0          8.80         f           s         u                    f
# 1          4.51         x           h         o                    f
# 2          6.94         f           s         b                    f
# 3          3.88         f           y         g                    f
# 4          5.85         x           l         w                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  stem-width  ...  \
# 0               a            c          w         4.51       15.39  ...
# 1               a            c          n         4.79        6.48  ...
# 2               x            c          w         6.85        9.93  ...
# 3               s          NaN          g         4.16        6.53  ...
# 4               d          NaN          w         3.37        8.36  ...
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# ...

# %%
main_dataset = pd.read_csv('/kaggle/input/secondary-mushroom-dataset-data-set/MushroomDataset/secondary_data.csv', sep=";")
label = main_dataset['class']
main_dataset = main_dataset.drop('class', axis=1)
main_dataset['class'] = label
main_dataset.head()
# Out:
#    cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0         15.26         x           g         o                    f
# 1         16.60         x           g         o                    f
# 2         14.07         x           g         o                    f
# 3         14.17         f           h         e                    f
# 4         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  stem-width  ...  \
# 0               e          NaN          w        16.95       17.09  ...
# 1               e          NaN          w        17.99       18.19  ...
# 2               e          NaN          w        17.80       17.74  ...
# 3               e          NaN          w        15.77       15.98  ...
# 4               e          NaN          w        16.53       17.20  ...
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# ...

# %%
df_test = pd.read_csv('test.csv').drop('id', axis=1)
df_test.head()
# Out:
#    cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0          8.64         x         NaN         n                    t
# 1          6.90         o           t         o                    f
# 2          2.00         b           g         n                    f
# 3          3.47         x           t         n                    f
# 4          6.17         x           h         y                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  stem-width stem-root  \
# 0             NaN          NaN          w        11.13       17.12         b
# 1             NaN            c          y         1.27       10.75       NaN
# 2             NaN            c          n         6.18        3.14       NaN
# 3               s            c          n         4.98        8.51       NaN
# 4               p          NaN          y         6.73       13.70       NaN
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 3116945 entries, 0 to 3116944
#
# Data columns (total 21 columns):
#
#  #   Column                Dtype
#
# ---  ------                -----
#
#  0   cap-diameter          float64
#
#  1   cap-shape             object
#
#  2   cap-surface           object
#
#  3   cap-color             object
#
#  4   does-bruise-or-bleed  object
#
#  5   gill-attachment       object
#
#  6   gill-spacing          object
#
#  7   gill-color            object
#
#  8   stem-height           float64
#
#  9   stem-width            float64
#
#  10  stem-root             object
#
#  11  stem-surface          object
#
#  12  stem-color            object
#
#  13  veil-type             object
#
#  14  veil-color            object
#
#  15  has-ring              object
#
#  16  ring-type             object
#
#  17  spore-print-color     object
#
#  18  habitat               object
#
#  19  season                object
#
#  20  class                 object
#
# ...

# %%
main_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 61069 entries, 0 to 61068
#
# Data columns (total 21 columns):
#
#  #   Column                Non-Null Count  Dtype
#
# ---  ------                --------------  -----
#
#  0   cap-diameter          61069 non-null  float64
#
#  1   cap-shape             61069 non-null  object
#
#  2   cap-surface           46949 non-null  object
#
#  3   cap-color             61069 non-null  object
#
#  4   does-bruise-or-bleed  61069 non-null  object
#
#  5   gill-attachment       51185 non-null  object
#
#  6   gill-spacing          36006 non-null  object
#
#  7   gill-color            61069 non-null  object
#
#  8   stem-height           61069 non-null  float64
#
#  9   stem-width            61069 non-null  float64
#
#  10  stem-root             9531 non-null   object
#
#  11  stem-surface          22945 non-null  object
#
#  12  stem-color            61069 non-null  object
#
#  13  veil-type             3177 non-null   object
#
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 2077964 entries, 0 to 2077963
#
# Data columns (total 20 columns):
#
#  #   Column                Dtype
#
# ---  ------                -----
#
#  0   cap-diameter          float64
#
#  1   cap-shape             object
#
#  2   cap-surface           object
#
#  3   cap-color             object
#
#  4   does-bruise-or-bleed  object
#
#  5   gill-attachment       object
#
#  6   gill-spacing          object
#
#  7   gill-color            object
#
#  8   stem-height           float64
#
#  9   stem-width            float64
#
#  10  stem-root             object
#
#  11  stem-surface          object
#
#  12  stem-color            object
#
#  13  veil-type             object
#
#  14  veil-color            object
#
#  15  has-ring              object
#
#  16  ring-type             object
#
#  17  spore-print-color     object
#
#  18  habitat               object
#
#  19  season                object
#
# dtypes: float64(3), object(17)
#
# ...

# %%
def checking(df):
  total = len(df)
  null_df = pd.DataFrame(df.isnull().sum(), columns=['#NULLS'])
  null_df['%NULLS'] = round((null_df['#NULLS']/total)*100, 5)
  null_df['#Unique_Valus'] = df.nunique()
  cat_cols = [col for col in df.columns if df[col].dtype == 'object']
  uniques = []
  for col in df.columns:
    if col in cat_cols:
      uniques.append(set(df[col].dropna()))
    else:
     uniques.append(df[col].max() - df[col].min())
  null_df['Unique_Values'] = uniques
  return null_df

# %%
checking(df_train)
# Out:
#                        #NULLS    %NULLS  #Unique_Valus  \
# cap-diameter                4   0.00013           3913
# cap-shape                  40   0.00128             74
# cap-surface            671023  21.52823             83
# cap-color                  12   0.00038             78
# does-bruise-or-bleed        8   0.00026             26
# gill-attachment        523936  16.80928             78
# gill-spacing          1258435  40.37399             48
# gill-color                 57   0.00183             63
# stem-height                 0   0.00000           2749
# stem-width                  0   0.00000           5836
# stem-root             2757023  88.45273             38
# stem-surface          1980861  63.55136             60
# stem-color                 38   0.00122             59
# veil-type             2957493  94.88435             22
# veil-color            2740947  87.93697             24
# has-ring                   24   0.00077             23
# ...

# %%
checking(main_dataset)
# Out:
#                       #NULLS    %NULLS  #Unique_Valus  \
# cap-diameter               0   0.00000           2571
# cap-shape                  0   0.00000              7
# cap-surface            14120  23.12139             11
# cap-color                  0   0.00000             12
# does-bruise-or-bleed       0   0.00000              2
# gill-attachment         9884  16.18497              7
# gill-spacing           25063  41.04046              3
# gill-color                 0   0.00000             12
# stem-height                0   0.00000           2226
# stem-width                 0   0.00000           4630
# stem-root              51538  84.39306              5
# stem-surface           38124  62.42775              8
# stem-color                 0   0.00000             13
# veil-type              57892  94.79769              1
# veil-color             53656  87.86127              6
# has-ring                   0   0.00000              2
# ...

# %%
checking(df_test)
# Out:
#                        #NULLS    %NULLS  #Unique_Valus  \
# cap-diameter                7   0.00034           3745
# cap-shape                  31   0.00149             62
# cap-surface            446904  21.50682             59
# cap-color                  13   0.00063             57
# does-bruise-or-bleed       10   0.00048             22
# gill-attachment        349821  16.83480             66
# gill-spacing           839595  40.40469             35
# gill-color                 49   0.00236             56
# stem-height                 1   0.00005           2664
# stem-width                  0   0.00000           5610
# stem-root             1838012  88.45254             31
# stem-surface          1321488  63.59533             54
# stem-color                 21   0.00101             55
# veil-type             1971545  94.87869             15
# veil-color            1826124  87.88044             23
# has-ring                   19   0.00091             23
# ...

# %%
def outliers_detection(df, q1_coef=0.25, q3_coef=0.75):
  data_out = df.copy()
  outlier_counts = {}

  cat_cols = [col for col in data_out.columns if data_out[col].dtype == 'object']
  num_cols = [col for col in data_out.columns if col not in cat_cols]

  for col in num_cols:
    q1=data_out[col].quantile(q1_coef)
    q3=data_out[col].quantile(q3_coef)
    iqr = q3 - q1
    outlier_counts[col]=[len(data_out[(data_out[col]<q1-1.5*iqr) | (data_out[col]>q3+1.5*iqr)])]

  for col in cat_cols:
    value_counts = data_out[col].value_counts()
    threshold = 0.05*len(data_out)
    rare_values = value_counts[value_counts<threshold].index
    outlier_counts[col]=[len(data_out[data_out[col].isin(rare_values)])]

  outlier_df = pd.DataFrame(outlier_counts).T
  outlier_df.columns = ['Number of Outliers']
  return outlier_df

# %%
outliers_detection(df_train)
# Out:
#                       Number of Outliers
# cap-diameter                       76124
# stem-height                       132419
# stem-width                         66481
# cap-shape                         320849
# cap-surface                       517328
# cap-color                         404360
# does-bruise-or-bleed                 109
# gill-attachment                   120454
# gill-spacing                      119524
# gill-color                        459591
# stem-root                         194121
# stem-surface                      328628
# stem-color                        542835
# veil-type                             79
# veil-color                         96928
# has-ring                             119
# ring-type                         510895
# spore-print-color                 267263
# habitat                           312527
# season                            141847
# class                                  0

# %%
outliers_detection(main_dataset)
# Out:
#                       Number of Outliers
# cap-diameter                        2400
# stem-height                         3169
# stem-width                          1967
# cap-shape                           4413
# cap-surface                        10674
# cap-color                           8531
# does-bruise-or-bleed                   0
# gill-attachment                        0
# gill-spacing                           0
# gill-color                          9726
# stem-root                           3177
# stem-surface                        7584
# stem-color                         12215
# veil-type                              0
# veil-color                          1939
# has-ring                               0
# ring-type                          10237
# spore-print-color                   6354
# habitat                             5749
# season                              2727
# class                                  0

# %%
outliers_detection(df_test)
# Out:
#                       Number of Outliers
# cap-diameter                       51122
# stem-height                        88229
# stem-width                         44766
# cap-shape                         213047
# cap-surface                       345130
# cap-color                         268769
# does-bruise-or-bleed                  65
# gill-attachment                    79952
# gill-spacing                       79308
# gill-color                        305319
# stem-root                         129371
# stem-surface                      219326
# stem-color                        362281
# veil-type                             46
# veil-color                         65408
# has-ring                              94
# ring-type                         341569
# spore-print-color                 178347
# habitat                           208761
# season                             94637

# %%
def find_new_categories(generated_dataset, main_dataset, col):
  main_unique_values = set(main_dataset[col].dropna().unique())
  outliers_in_col = generated_dataset[~generated_dataset[col].isin(main_unique_values)]
  return outliers_in_col['class']

# %%
cat_cols = [col for col in df_train.columns if df_train[col].dtype == 'object']
new_category = pd.DataFrame(columns=['Column', 'e_class', 'p_class'])

for col in cat_cols:
    new_category_rows = find_new_categories(df_train, main_dataset, col)
    e_class_count = new_category_rows[new_category_rows == 'e'].count()
    p_class_count = new_category_rows[new_category_rows == 'p'].count()
    temp_concat = pd.DataFrame({'Column': [col], 'e_class': [e_class_count], 'p_class': [p_class_count]})
    new_category = pd.concat((new_category, temp_concat), axis=0)

new_category
# Out:
#                  Column  e_class  p_class
# 0             cap-shape      251      316
# 0           cap-surface   326462   345163
# 0             cap-color      173      194
# 0  does-bruise-or-bleed       56       61
# 0       gill-attachment   189368   335069
# 0          gill-spacing   540132   718447
# 0            gill-color      211      281
# 0             stem-root  1268497  1488709
# 0          stem-surface   965506  1015751
# 0            stem-color      124      172
# 0             veil-type  1356658  1600914
# 0            veil-color  1242595  1498493
# 0              has-ring       65       78
# 0             ring-type    78121    51159
# 0     spore-print-color  1342112  1507744
# 0               habitat      238      254
# 0                season        0        0
# 0                 class        0        0

# %%
tem_df = main_dataset[['cap-diameter', 'stem-height', 'stem-width', 'class']]
sns.pairplot(tem_df, hue='class')
plt.show()

# %%
tem_df = df_train[['cap-diameter', 'stem-height', 'stem-width', 'class']]
sns.pairplot(tem_df, hue='class')
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
import matplotlib.pyplot as plt
import seaborn as sns

tem_df1 = df_train[['cap-diameter', 'stem-height']]
tem_df2 = df_train[['cap-diameter', 'stem-width']]
tem_df3 = df_train[['stem-height', 'stem-width']]

X1 = tem_df1.fillna(0)
X2 = tem_df2.fillna(0)
X3 = tem_df3.fillna(0)

# K-Means Clustering
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans_labels1 = kmeans.fit_predict(X1)

kmeans = KMeans(n_clusters=2, random_state=42)
kmeans_labels2 = kmeans.fit_predict(X2)

kmeans = KMeans(n_clusters=2, random_state=42)
kmeans_labels3 = kmeans.fit_predict(X3)

# Visualize clustering results
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

sns.scatterplot(x='cap-diameter', y='stem-height', hue=kmeans_labels1, data=tem_df1, ax=axes[0])
axes[0].set_title('K-Means Clustering 1')

sns.scatterplot(x='cap-diameter', y='stem-width', hue=kmeans_labels2, data=tem_df2, ax=axes[1])
axes[1].set_title('K-Means Clustering 2')

sns.scatterplot(x='stem-height', y='stem-width', hue=kmeans_labels3, data=tem_df3, ax=axes[2])
axes[2].set_title('K-Means Clustering 3')

plt.show()

# %%
# Gaussian Mixture Model
gmm = GaussianMixture(n_components=2, random_state=42)
gmm_labels1 = gmm.fit_predict(X1)

gmm = GaussianMixture(n_components=2, random_state=42)
gmm_labels2 = gmm.fit_predict(X2)

gmm = GaussianMixture(n_components=2, random_state=42)
gmm_labels3 = gmm.fit_predict(X3)

# Visualize clustering results
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

sns.scatterplot(x='cap-diameter', y='stem-height', hue=gmm_labels1, data=tem_df1, ax=axes[0])
axes[0].set_title('GMM Clustering 1')

sns.scatterplot(x='cap-diameter', y='stem-width', hue=gmm_labels2, data=tem_df2, ax=axes[1])
axes[1].set_title('GMM Clustering 2')

sns.scatterplot(x='stem-height', y='stem-width', hue=gmm_labels3, data=tem_df3, ax=axes[2])
axes[2].set_title('GMM Clustering 3')

plt.show()

# %% [markdown]
# ##Data Distribution

# %%
def plot_distribution(generated_dataset, main_dataset, column):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    sns.countplot(y=column, data=generated_dataset, order=generated_dataset[column].value_counts().index, palette="viridis")
    plt.title(f'Distribution of {column} in Generated Data')

    plt.subplot(1, 2, 2)
    sns.countplot(y=column, data=main_dataset, order=main_dataset[column].value_counts().index, palette="viridis")
    plt.title(f'Distribution of {column} in Main Data')

    plt.tight_layout()
    plt.show()

# %%
cat_cols = [col for col in df_train.columns if df_train[col].dtype == 'object']

for col in cat_cols:
  plot_distribution(df_train, main_dataset, col)
  plt.show()

# %% [markdown]
# # Outlier handling

# %%
def outliers_handeling(df, q1_coef=0.25, q3_coef=0.75, iqr_coef=1.5):
    data_out = df.copy()
    cat_cols = [col for col in data_out.columns if data_out[col].dtype == 'object']
    num_cols = [col for col in data_out.columns if col not in cat_cols]

    for col in num_cols:
        q1=data_out[col].quantile(q1_coef)
        q3=data_out[col].quantile(q3_coef)
        iqr = q3 - q1
        data_out.loc[(data_out[col] < q1 - iqr_coef*iqr), col] = q1 - iqr_coef*iqr
        data_out.loc[(data_out[col] > q3 + iqr_coef*iqr), col] = q3 + iqr_coef*iqr

    for col in cat_cols:
        value_counts = data_out[col].value_counts()
        threshold = 100
        rare_values = value_counts[value_counts<threshold].index
        data_out[col] = data_out[col].apply(lambda x: 'Other' if x in rare_values else x)

    return data_out

# %%
without_outliers_train = outliers_handeling(df_train)
without_outliers_test = outliers_handeling(df_test)

# %%
for col in cat_cols:
  plot_distribution(without_outliers_train, main_dataset, col)
  plt.show()
